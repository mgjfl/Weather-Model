# %%
import sys
import os
sys.path.append(os.path.abspath("../.."))
from Data import *

# %%
T = 250
d = 5
w = 4

test = PeriodicGaussianData(d, w)
data = test.generate(T)

# %%
datap = DataProcessing(data)

# %%
datap.visualizeData()
