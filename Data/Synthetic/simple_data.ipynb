# %%
import sys
import os
sys.path.append(os.path.abspath("../.."))
from Data import *

# %%
T = 250
d = 5
w = 4

test = LinearGaussian(d, w)
data = test.generate(T, 2)

# %%
datap = DataProcessing(data)

# %%
datap.visualizeData()

# %%
n = w * d

torch.manual_seed(1)

a = 2
A = torch.stack([torch.randn((n,)) + torch.randn((1,))*a for i in range(n)])
# print(A)
A = A @ A.T
# print(torch.diag(A))
D_half = torch.diag(torch.diag(A)**(-0.5))
# print(D_half)
C = D_half @ A @ D_half
# print(torch.diag(torch.cholesky(C)))
print(torch.diag(C))
# Out:
# tensor([1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#         1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#         1.0000, 1.0000])
